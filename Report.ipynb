# %% [markdown]
# ## REPORT ON BATTLE OF THE NEIGHBORHOODS
#
#  ### Abubakar Usman
#
# ####  August, 2019

# %% [markdown]
# #### Introduction
#
# With a population of almost 3 million as at 2016 estimates, Toronto is the most populous city in Canada. It is also the fastest growing city in North America (Wikipedia) and is recognized as one of the most multicultural and cosmopolitan cities in the world. The diverse population of Toronto reflects its current and historical role as an important destination for immigrants to Canada. More than 50 percent of residents belong to a visible minority population group and over 200 distinct ethnic origins are represented among its inhabitants.
#
# As with any big city around the world, residents and newcomers to Toronto are faced with a challenge on deciding which part of the city to settle, move to or open a business in order to enjoy the best of both worlds. For residents, commuting to and from work can be a daily pain most especially if living on the opposite edges of the city; finding suitable spots for weekend hang outs with friends can be a weekly debate sessions and setting up a new business can be tough due to the diverse nature of the city and the spread of the target customers. For newcomers to the city, the key considerations are usually affordable housing, schools for their young kids, community engagements and easy access to grocery stores and shopping. This is a top challenge that requires a solution to help guide these categories of people living in Toronto or planning to make a move into the city.
#
# This analysis will attempt to provide a data-driven guided tour of all that is or is not available to make an informed decision to make that move to a new neighborhood, settle in open or expand that business into a new neighborhood in the city. To guide a business owner on where to set up the next shop or open a new office, the analysis would provide a picture of possible demand by providing additional data on the number of households or population in each neighborhood.

# %% [markdown]
# #### Data Acquisition and Cleaning
#
# The data used was pulled from location data provided by Foursquare API, Wikipedia, and Statistics Canada based on latitudes and longitudes of each postcode in Toronto. Each neighborhood belongs to a postcode and a number of postcodes make up a Borough. All neighborhoods within the same postcode were combined to form a combined neighborhood for ease of analysis. After cleaning-up the data, there were a total of 103 records representing each postcode within the city.
#
# For each postcode, all places of interests such as restaurants, coffee shops, parks, schools, shopping malls, farmers markets, recreation centers, etc., were categorised and ranked based on being the most common in each neighborhood. Below is a snapshot of the first few records of the data.
#
# ![image.png](attachment:image.png)

# %% [markdown]
#  ### Methodology
#
# #### 1.0 Exploratory Data Analysis
#
# To get a bird’s eye view of the spatial distribution of all the neighborhoods in Toronto, a map was plotted using folium package. This is shown below.
#
# ![image.png](attachment:image.png)
#
# The green markers represent each of the 103 postcodes. Each postcode has at least one neighborhood. As expected of any major city, the downtown core is more compact and dense. The neighborhoods spread out as you move away from the downtown towards the suburbs.

# %% [markdown]
# #### 2.0 Exploring Venues and Clustering
#
# To explore the venues of interest in each postcode, the Foursquare API was used in collecting data within 500 radius of at most 100 venues. However, the data collected from the API was sparse and hard to get the big picture. Therefore the one-hot technique was employed in order to pick out the first-ten most common venues in each postcode. A snapshot of the results obtained is shown below.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Most of the venues returned by the API showed high volume of restaurants, coffee shops, drugstores and fitness studios.
#
# To get a more refined picture of the most common venues in each neighborhood, the K-Means Clustering technique was used in grouping postcodes that have similar venues. A total of 7 clusters were found as shown in the map below.
#
# ![image.png](attachment:image.png)
